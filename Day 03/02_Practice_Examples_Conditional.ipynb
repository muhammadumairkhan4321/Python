# %% [markdown]
# # Practice Examples - Conditional Statements in Python
#
# GitHub-ready notebook with explanations.
#
# ## Topics Covered
# - if
# - if-else
# - if-elif-else
# - Nested if

# %%
# Conditional statement example
# This code demonstrates decision making in Python.

age = int(input("Enter age: "))

print("Your Age: ",age)

if age < 13:
    print("Child")
elif (age >= 13 and age < 18):
    print("Teenager")
else:
    print("Adult")
# Out:
# Your Age:  8
# Child

# %%
# Conditional statement example
# This code demonstrates decision making in Python.

age = int(input("Enter age: "))

print("Your Age: ",age)

if age < 13:
    print("Child")
elif (age >= 13 and age < 18):
    print("Teenager")
else:
    print("Adult")
# Out:
# Your Age:  17
# Teenager

# %%
# Conditional statement example
# This code demonstrates decision making in Python.

age = int(input("Enter age: "))

print("Your Age: ",age)

if age < 13:
    print("Child")
elif (age >= 13 and age < 18):
    print("Teenager")
else:
    print("Adult")
# Out:
# Your Age:  22
# Adult

# %%
# Conditional statement example
# This code demonstrates decision making in Python.

username = input("Enter Username: ")
password = input("Enter password: ")

print("Username: ",username)
print("Password: ",password)

if (username == "admin" and password == "pass"):
    print("Login Successful!")
elif (username != "admin"):
    print("Wrong Username")
else:
    print("Wrong Password")
# Out:
# Username:  admin
# Password:  pass
# Login Successful!

# %%
# Conditional statement example
# This code demonstrates decision making in Python.

username = input("Enter Username: ")
password = input("Enter password: ")

print("Username: ",username)
print("Password: ",password)

if (username == "admin" and password == "pass"):
    print("Login Successful!")
elif (username != "admin"):
    print("Wrong Username")
else:
    print("Wrong Password")
# Out:
# Username:  Ali
# Password:  pass
# Wrong Username

# %%
# Conditional statement example
# This code demonstrates decision making in Python.

username = input("Enter Username: ")
password = input("Enter password: ")

print("Username: ",username)
print("Password: ",password)

if (username == "admin" and password == "pass"):
    print("Login Successful!")
elif (username != "admin"):
    print("Wrong Username")
else:
    print("Wrong Password")
# Out:
# Username:  admin
# Password:  1432
# Wrong Password

# %%
# Conditional statement example
# This code demonstrates decision making in Python.

username = input("Enter Username: ")
password = input("Enter password: ")

print("Username: ",username)
print("Password: ",password)

if (username == "admin" and password == "pass"):
    print("Login Successful!")
elif (username != "admin" and password != "pass"):
    print("Wrong Username and Password!")
elif (username != "admin"):
    print("Wrong Username")
else:
    print("Wrong Password")
# Out:
# Username:  adimn
# Password:  134
# Wrong Username and Password!

# %%
# Conditional statement example
# This code demonstrates decision making in Python.

n = int(input("Enter Any Number:"))

print(n)

if (n % 5 == 0):
    print("Multiple of 5")
else:
    print("not a Multiple of 5")
# Out:
# 25
# Multiple of 5

# %%
# Conditional statement example
# This code demonstrates decision making in Python.

n = int(input("Enter Any Number:"))

print(n)

if (n % 5 == 0):
    print("Multiple of 5")
else:
    print("not a Multiple of 5")
# Out:
# 56
# not a Multiple of 5

# %% [markdown]
# ## Practice Challenge
# Write a program to display grades based on marks.

# %%
marks=int(input("Enter your marks: "))
if marks>=90:
    print("Grade: A")
elif marks>=80:
    print("Grade: B")
elif marks>=70:
    print("Grade: C")
else:
    print("Need Improvement")
