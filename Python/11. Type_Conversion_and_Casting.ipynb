# %% [markdown]
# # Type Conversion and Type Casting in Python
#
# This notebook explains implicit type conversion and explicit type casting with simple examples.
#
# ## Topics Covered
# - Type Conversion
# - Type Casting
# - int()
# - float()
# - str()
# - bool()

# %%
# Example of type conversion / type casting
# This example demonstrates how Python converts data types.

# Type Conversion And Casting
# int --> float (Allowed)
# float --> int (Allowed)
# int --> bool (Allowed)

# %%
# Example of type conversion / type casting
# This example demonstrates how Python converts data types.

# "123" --> int (123)

# %%
# Example of type conversion / type casting
# This example demonstrates how Python converts data types.

# Type Conversion
# 1. type Conversion (implicit --> python) Automatically
# eg: float + int = float
# 2. Casting (Explicit --> dev)

# %%
# Example of type conversion / type casting
# This example demonstrates how Python converts data types.

a = 10 
b = 5

print(a / b)
print(type(a / b))
# Out:
# 2.0
# <class 'float'>

# %%
# Example of type conversion / type casting
# This example demonstrates how Python converts data types.

ans = 5 + 10.0

print(ans)
# Out:
# 15.0

# %%
# Example of type conversion / type casting
# This example demonstrates how Python converts data types.
