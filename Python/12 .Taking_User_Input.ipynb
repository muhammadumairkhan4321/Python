# %% [markdown]
# # Taking User Input in Python
#
# This notebook explains how to take input from users using the `input()` function.
#
# ## Topics Covered
# - `input()`
# - User Input
# - Type Conversion with `int()` and `float()`
# - Practical Examples

# %% [markdown]
# # **Taking Input**

# %%
# Taking user input example
# The input() function accepts data from the user.

Your_Name = input("Enter Your Name: ")
print("Hello,", Your_Name)
# Out:
# Hello, Muhammad Umair Khan

# %%
# Taking user input example
# The input() function accepts data from the user.

Your_Age =input("Your Age :")
print("Age :",Your_Age)
# Out:
# Age : 18 Years

# %%
# Taking user input example
# The input() function accepts data from the user.

a = input("Enter Any Number")
b = input("Enter Another Name")

Sum = a + b

print("First No :",a)
print("Second No :",b)
print(Sum)
# Out:
# First No : 21
# Second No : 45
# 2145

# %%
# Taking user input example
# The input() function accepts data from the user.

a = int(input("Enter Any Number"))
b = int(input("Enter Another Name"))

Sum = a + b

print("First No :",a)
print("Second No :",b)
print(Sum)
# Out:
# First No : 65
# Second No : 13
# 78

# %% [markdown]
# ## Practice Exercise
#
# Try creating a program that:
# 1. Takes the user's name.
# 2. Takes the user's age.
# 3. Prints a welcome message with both values.

# %%
# Practice Example

name = input("Enter your name: ")
age = int(input("Enter your age: "))

print(f"Welcome {name}!")
print(f"You are {age} years old.")
# Out:
# Welcome Muhammad Umair Khan!
# You are 18 years old.
